# %% [markdown]
# # Buscador de Documentos públicos Markdown com Embeddings no GitHub
#
# ## Primeiro construir um dataframe com as colunas url, titulo e conteudo dos documentos Markdown encontrados dentro do repositório informado

# %%
import requests
import base64
import pandas as pd

def get_markdown_files(owner, repo):
    # Obter último commit da branch master
    branch_url = f"https://api.github.com/repos/{owner}/{repo}/branches/master"
    branch_response = requests.get(branch_url)
    
    # Verificar se a branch master existe
    if branch_response.status_code == 404:
        print("A branch 'master' não existe neste repositório.")
        return pd.DataFrame() # retorna um DataFrame vazio se a branch não existir
    
    commit_sha = branch_response.json()["commit"]["sha"]

    # Obter árvore do commit
    commit_url = f"https://api.github.com/repos/{owner}/{repo}/commits/{commit_sha}"
    commit_response = requests.get(commit_url)
    tree_sha = commit_response.json()["commit"]["tree"]["sha"]

    # Obter conteúdo da árvore
    tree_url = f"https://api.github.com/repos/{owner}/{repo}/git/trees/{tree_sha}?recursive=1"
    tree_response = requests.get(tree_url)
    tree_content = tree_response.json()

    # Verificar se a chave 'tree' existe na resposta
    if "tree" in tree_content:
        tree_content = tree_content["tree"]
    else:
        print("A resposta da API não contém a chave 'tree'.")
        return pd.DataFrame()

    # Filtrar arquivos .md e obter seu conteúdo
    data = []  # Lista para armazenar os dados
    for file in tree_content:
        if file["path"].endswith(".md"):
            blob_sha = file["sha"]
            blob_url = f"https://api.github.com/repos/{owner}/{repo}/git/blobs/{blob_sha}"
            blob_response = requests.get(blob_url)
            content = base64.b64decode(blob_response.json()["content"]).decode("utf-8")

            # Construir link completo do arquivo no GitHub
            file_url = f"https://github.com/{owner}/{repo}/blob/master/{file['path']}"

              # Encontrar o título
            lines = content.split('\n')
            title = ''
            found_title = False
            for line in lines:
                if not found_title and line.strip():
                    title += line.strip() + ' '
                    found_title = True
                elif found_title and line.strip():
                    title += line.strip()
                    break

            data.append({"url": file_url, "conteudo": content, "titulo": title})

    # Criar DataFrame
    df = pd.DataFrame(data)
    return df

# Exemplo de uso
df_markdown = get_markdown_files("marcosab10", "ICMC-USP")
print(df_markdown)
# Out:
#                                                   url  \
# 0   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 1   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 2   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 3   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 4   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 5   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 6   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 7   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 8   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 9   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 10  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 11  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 12  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 13  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 14  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 15  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 16  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 17  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 18  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 19  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 20  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 21  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 22  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 23  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 24  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 25  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 26  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 27  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 28  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 29  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 30  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 31  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 32  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 33  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 34  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 35  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 36  https://github.com/marcosab10/ICMC-USP/blob/ma...
#
#                                              conteudo  \
# 0   ## Windows CMD Commands\n\n - A maioria dos co...
# 1   ### Learning Git\n\n - References\n    - [Magi...
# 2   ## Linux Commands\n\n#### Source/Credits: http...
# 3   ## Structured Query Language\n\n - Sites\n    ...
# 4   # Título 1\n\n## Título 2\n\n### Título 3\n\n#...
# 5   # Parágrafos\n\nLorem ipsum dolor sit amet, co...
# 6   # Ênfase\n\n## Negrito 1\n\n**Lorem** ipsum do...
# 7   # Linhas horizontais\n\n## Exemplo 1\n\n***\n-...
# 8   # Listas não-ordenadas 1\n\n* Item 01\n* Item ...
# 9   # Listas ordenadas 1\n\n1. Item 01\n2. Item 02...
# 10  # Links\n\n## Link 1\n\n[Clique aqui](https://...
# 11  # Imagens\n\n## Imagem 1\n\n![Markdown](images...
# 12  # Tabelas\n\n# Exemplo 1\n\n| Nome | Idade |\n...
# 13  # Códigos\n\n# Exemplo em linha\n\nInforme os ...
# 14  # GitHub\n\n# Lista de tarefas\n\n* [ ] Item 1...
# 15  # OSS Project Generator\n\n[![Travis Status][t...
# 16  ## Learning Marketing Digital :smile:\n\n - Th...
# 17  \n - <strong>Referências</strong>\n   - [Árvor...
# 18  ## English\n\n- [Mairo Vergara](http://www.mai...
# 19  <p align="center">\n  "<strong>If you know the...
# 20   - http://www.cs.usfca.edu/galles/visualizatio...
# 21  ### Estudos e análise de algoritmos\n\n - <str...
# 22  ## Learning Economics, Finances & Accounting :...
# 23   - Link Schemelt (esquemático online)\n\n    -...
# 24  https://www.thegeekstuff.com/2012/01/linux-ino...
# 25  https://www.geeksforgeeks.org/greedy-algorithm...
# 26  ## Referencias\n\n- [Arvore B - Wikipedia](htt...
# 27  https://www.pctechguide.com/hard-disks/file-sy...
# 28  ## Bibliografia\n\n> SEDGEWICK, R. Algorithms ...
# 29  Especificação do Projeto 2\n\n\nFazer um progr...
# 30  \n - <strong>Referências</strong>\n   - [Árvor...
# 31  ## Exemplos de aplicações de estruturas de dad...
# 32    ### Exercicios do curso de Estrutura de Dados\n
# 33  \n - <strong>Referencias</strong>\n    - [UNIC...
# 34   - References\n    - [Origamid - UX Design Heu...
# 35  Prof. Dr. Edson W Cazarini\n\n"A História está...
# 36  ### Softwares\n   - [Draw.io](https://www.draw...
#
#                                                titulo
# 0   ## Windows CMD Commands - A maioria dos comand...
# 1                       ### Learning Git - References
# 2   ## Linux Commands #### Source/Credits: https:/...
# 3                ## Structured Query Language - Sites
# 4                              # Título 1 ## Título 2
# 5   # Parágrafos Lorem ipsum dolor sit amet, conse...
# 6                               # Ênfase ## Negrito 1
# 7                   # Linhas horizontais ## Exemplo 1
# 8                  # Listas não-ordenadas 1 * Item 01
# 9                     # Listas ordenadas 1 1. Item 01
# 10                                  # Links ## Link 1
# 11                              # Imagens ## Imagem 1
# 12                              # Tabelas # Exemplo 1
# 13                       # Códigos # Exemplo em linha
# 14                        # GitHub # Lista de tarefas
# 15  # OSS Project Generator [![Travis Status][trav...
# 16     ## Learning Marketing Digital :smile: - Theory
# 17  - <strong>Referências</strong> - [Árvore binár...
# 18  ## English - [Mairo Vergara](http://www.mairov...
# 19  <p align="center"> "<strong>If you know the en...
# 20  - http://www.cs.usfca.edu/galles/visualization...
# 21  ### Estudos e análise de algoritmos - <strong>...
# 22  ## Learning Economics, Finances & Accounting :...
# 23  - Link Schemelt (esquemático online) - https:/...
# 24  https://www.thegeekstuff.com/2012/01/linux-ino...
# 25  https://www.geeksforgeeks.org/greedy-algorithm...
# 26  ## Referencias - [Arvore B - Wikipedia](https:...
# 27  https://www.pctechguide.com/hard-disks/file-sy...
# 28  ## Bibliografia > SEDGEWICK, R. Algorithms in ...
# 29  Especificação do Projeto 2 Fazer um programa q...
# 30  - <strong>Referências</strong> - [Árvore binár...
# 31  ## Exemplos de aplicações de estruturas de dad...
# 32     ### Exercicios do curso de Estrutura de Dados
# 33  - <strong>Referencias</strong> - [UNICAMP](htt...
# 34  - References - [Origamid - UX Design Heuristic...
# 35  Prof. Dr. Edson W Cazarini "A História está re...
# 36    ### Softwares - [Draw.io](https://www.draw.io/)

# %% [markdown]
# ## Configuração de API Key e importação das libs numpy e google.generativeai

# %%
import numpy as np
import google.generativeai as genai


genai.configure(api_key="AIzaSyB2Oc0kaKu3BrC8xM4KgjHrWtU8IgrRSRo")

model = "models/embedding-001"

# %% [markdown]
# ## Criação da função de embed

# %%
def embed_fn(title, text):
    return genai.embed_content(model=model,
                               content=text,
                               title=title,
                               task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %% [markdown]
# ## Criação da coluna de Embeddings no dataframe

# %%
df_markdown["Embeddings"] = df_markdown.apply(lambda row: embed_fn(row["url"], row["conteudo"][:9000]), axis=1)
df_markdown
# Out:
#                                                   url  \
# 0   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 1   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 2   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 3   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 4   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 5   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 6   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 7   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 8   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 9   https://github.com/marcosab10/ICMC-USP/blob/ma...
# 10  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 11  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 12  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 13  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 14  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 15  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 16  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 17  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 18  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 19  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 20  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 21  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 22  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 23  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 24  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 25  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 26  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 27  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 28  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 29  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 30  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 31  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 32  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 33  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 34  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 35  https://github.com/marcosab10/ICMC-USP/blob/ma...
# 36  https://github.com/marcosab10/ICMC-USP/blob/ma...
#
#                                              conteudo  \
# 0   ## Windows CMD Commands\n\n - A maioria dos co...
# 1   ### Learning Git\n\n - References\n    - [Magi...
# 2   ## Linux Commands\n\n#### Source/Credits: http...
# 3   ## Structured Query Language\n\n - Sites\n    ...
# 4   # Título 1\n\n## Título 2\n\n### Título 3\n\n#...
# 5   # Parágrafos\n\nLorem ipsum dolor sit amet, co...
# 6   # Ênfase\n\n## Negrito 1\n\n**Lorem** ipsum do...
# 7   # Linhas horizontais\n\n## Exemplo 1\n\n***\n-...
# 8   # Listas não-ordenadas 1\n\n* Item 01\n* Item ...
# 9   # Listas ordenadas 1\n\n1. Item 01\n2. Item 02...
# 10  # Links\n\n## Link 1\n\n[Clique aqui](https://...
# 11  # Imagens\n\n## Imagem 1\n\n![Markdown](images...
# 12  # Tabelas\n\n# Exemplo 1\n\n| Nome | Idade |\n...
# 13  # Códigos\n\n# Exemplo em linha\n\nInforme os ...
# 14  # GitHub\n\n# Lista de tarefas\n\n* [ ] Item 1...
# 15  # OSS Project Generator\n\n[![Travis Status][t...
# 16  ## Learning Marketing Digital :smile:\n\n - Th...
# 17  \n - <strong>Referências</strong>\n   - [Árvor...
# 18  ## English\n\n- [Mairo Vergara](http://www.mai...
# 19  <p align="center">\n  "<strong>If you know the...
# 20   - http://www.cs.usfca.edu/galles/visualizatio...
# 21  ### Estudos e análise de algoritmos\n\n - <str...
# 22  ## Learning Economics, Finances & Accounting :...
# 23   - Link Schemelt (esquemático online)\n\n    -...
# 24  https://www.thegeekstuff.com/2012/01/linux-ino...
# 25  https://www.geeksforgeeks.org/greedy-algorithm...
# 26  ## Referencias\n\n- [Arvore B - Wikipedia](htt...
# 27  https://www.pctechguide.com/hard-disks/file-sy...
# 28  ## Bibliografia\n\n> SEDGEWICK, R. Algorithms ...
# 29  Especificação do Projeto 2\n\n\nFazer um progr...
# 30  \n - <strong>Referências</strong>\n   - [Árvor...
# 31  ## Exemplos de aplicações de estruturas de dad...
# 32    ### Exercicios do curso de Estrutura de Dados\n
# 33  \n - <strong>Referencias</strong>\n    - [UNIC...
# 34   - References\n    - [Origamid - UX Design Heu...
# 35  Prof. Dr. Edson W Cazarini\n\n"A História está...
# 36  ### Softwares\n   - [Draw.io](https://www.draw...
#
#                                                titulo  \
# 0   ## Windows CMD Commands - A maioria dos comand...
# 1                       ### Learning Git - References
# 2   ## Linux Commands #### Source/Credits: https:/...
# 3                ## Structured Query Language - Sites
# 4                              # Título 1 ## Título 2
# 5   # Parágrafos Lorem ipsum dolor sit amet, conse...
# 6                               # Ênfase ## Negrito 1
# 7                   # Linhas horizontais ## Exemplo 1
# 8                  # Listas não-ordenadas 1 * Item 01
# 9                     # Listas ordenadas 1 1. Item 01
# 10                                  # Links ## Link 1
# 11                              # Imagens ## Imagem 1
# 12                              # Tabelas # Exemplo 1
# 13                       # Códigos # Exemplo em linha
# 14                        # GitHub # Lista de tarefas
# 15  # OSS Project Generator [![Travis Status][trav...
# 16     ## Learning Marketing Digital :smile: - Theory
# 17  - <strong>Referências</strong> - [Árvore binár...
# 18  ## English - [Mairo Vergara](http://www.mairov...
# 19  <p align="center"> "<strong>If you know the en...
# 20  - http://www.cs.usfca.edu/galles/visualization...
# 21  ### Estudos e análise de algoritmos - <strong>...
# 22  ## Learning Economics, Finances & Accounting :...
# 23  - Link Schemelt (esquemático online) - https:/...
# 24  https://www.thegeekstuff.com/2012/01/linux-ino...
# 25  https://www.geeksforgeeks.org/greedy-algorithm...
# 26  ## Referencias - [Arvore B - Wikipedia](https:...
# 27  https://www.pctechguide.com/hard-disks/file-sy...
# 28  ## Bibliografia > SEDGEWICK, R. Algorithms in ...
# 29  Especificação do Projeto 2 Fazer um programa q...
# 30  - <strong>Referências</strong> - [Árvore binár...
# 31  ## Exemplos de aplicações de estruturas de dad...
# 32     ### Exercicios do curso de Estrutura de Dados
# 33  - <strong>Referencias</strong> - [UNICAMP](htt...
# 34  - References - [Origamid - UX Design Heuristic...
# 35  Prof. Dr. Edson W Cazarini "A História está re...
# 36    ### Softwares - [Draw.io](https://www.draw.io/)
#
#                                            Embeddings
# 0   [-0.00028735085, -0.011052267, -0.07824952, -0...
# 1   [0.032851085, -0.013950162, -0.027780956, -0.0...
# 2   [0.0019569362, -0.008534544, -0.022349399, -0....
# 3   [0.0134508675, -0.036066815, -0.055087853, -0....
# 4   [0.023799047, -0.036072277, -0.039160665, 0.01...
# 5   [0.055545863, -0.017898032, -0.025671465, 0.01...
# 6   [0.03740417, -0.01904494, -0.05094322, 0.01915...
# 7   [0.0037895082, -0.037596505, -0.038943943, 0.0...
# 8   [-0.0036699108, -0.012538876, -0.04924564, -0....
# 9   [0.0017971874, -0.024890495, -0.07298121, -0.0...
# 10  [0.022850828, -0.023153208, -0.045224313, -0.0...
# 11  [0.009027333, -0.020937791, -0.0652471, -0.007...
# 12  [0.010785139, -0.04204041, -0.03770035, 0.0373...
# 13  [0.04315216, -0.03513013, -0.024058769, -0.019...
# 14  [0.031975746, -0.020804329, -0.058725018, -0.0...
# 15  [0.040511824, -0.09047522, -0.04184399, -0.008...
# 16  [0.06195571, -0.061241746, -0.017579744, 0.025...
# 17  [0.039058752, -0.04524922, -0.077620156, -0.00...
# 18  [-0.009729014, -0.019111425, -0.018985119, -0....
# 19  [0.025549352, -0.031468045, -0.024428144, -0.0...
# 20  [0.014500614, -0.031646542, -0.04954149, 0.021...
# 21  [0.01925924, -0.017828554, -0.047046646, 0.007...
# 22  [0.028656537, -0.06599228, -0.018866474, -0.00...
# 23  [0.011732247, -0.0060702194, -0.05030768, -0.0...
# 24  [0.017999297, 0.019026654, -0.036280964, -0.03...
# 25  [0.033951644, -0.01531536, -0.04283146, -0.034...
# 26  [0.027249515, -0.03121473, -0.028987003, -0.00...
# 27  [0.038681645, 0.00037300173, -0.04871662, -0.0...
# 28  [0.036014218, -0.008700594, -0.054121997, -0.0...
# 29  [0.004094563, -0.04336082, -0.0470109, 0.02072...
# 30  [0.0343523, -0.059003394, -0.087236606, 0.0024...
# 31  [0.030301694, -0.023575641, -0.05014467, 0.015...
# 32  [0.035840135, -0.010064274, -0.03035675, 0.009...
# 33  [0.039100323, 0.00182024, -0.045418702, -0.005...
# 34  [-0.0041150246, -0.012481842, -0.01779767, 0.0...
# 35  [0.039721157, -0.047434796, -0.05837121, 0.044...
# 36  [0.06099972, -0.02197954, -0.05342268, 0.00199...

# %% [markdown]
# ## Criação da função gera_e_buscar_consulta

# %%
def gera_e_buscar_consulta(consulta, base, model):
    embedding_da_consulta =  genai.embed_content(model=model,
                               content=consulta,
                               task_type="RETRIEVAL_QUERY")["embedding"]
    
    produtos_escalares = np.dot(np.stack(base["Embeddings"]), embedding_da_consulta)

    indice = np.argmax(produtos_escalares)
    return df_markdown.iloc[indice]["url"]

# %% [markdown]
# ## Finalmente executar a busca do documento que mais se aproxima da consulta

# %%
consulta = "Ganhar Dinheiro explicado por Kiyosaki"

url_encontrada = gera_e_buscar_consulta(consulta, df_markdown, model)
print(url_encontrada)
# Out:
# https://github.com/marcosab10/ICMC-USP/blob/master/USP - Economia & Investimentos/README.md
